# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
file_path = 'seq_with_dis.csv'
output_model_path = 'model/cvae_model_vmim_2.pt'
output_images_path = 'images'
output_npz_path = 'results'
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")

def ensure_directory_exists(path):
    """Ensure directory exists; if not, create it."""
    if path and not os.path.exists(path):
        os.makedirs(path, exist_ok=True)

# Ensure directories for model, logs, and images exist
ensure_directory_exists(os.path.dirname(output_model_path))
ensure_directory_exists(output_images_path)
ensure_directory_exists(output_npz_path)

# Dataset
class RegressionDataset(Dataset):
    def __init__(self, X_data, y_data):
        self.X_data = X_data
        self.y_data = y_data

    def __getitem__(self, index):
        return self.X_data[index], self.y_data[index]

    def __len__(self):
        return len(self.X_data)

def oneHotter(seqs):
    charToInt = {"A": 0, "C": 1, "G": 2, "T": 3}
    return [charToInt[let] for let in seqs]

def load_data_set_seq2seq(file_path, batch_size_=16, split=.2, ynormfac=22., verbose=False):
    df = pd.read_csv(file_path)
    df = df.reset_index(drop=True)

    seqs = df.Sequence.values
    lengths = [len(s) for s in seqs]

    min_length_measured = min(lengths)
    max_length_measured = max(lengths)

    condLen = 64
    disColnames = [" dis " + str(i) for i in range(0, condLen)]

    # y_data = np.array(df[disColnames])
    y_data = df[disColnames]
    # y_data = y_data.apply(lambda x: (x - x.min()) / (x.max() - x.min()))
    # y_data = y_data.apply(lambda x: (x) / (x.max()))
    y_data = np.array(y_data)
    # y_data = y_data/y_data.max(axis=1)[:,None]
    y_data = y_data/y_data.max()
    print(" ********    dddd    ", np.max(y_data.max()))
    ##
    X = np.array(df.Sequence.apply(oneHotter).tolist())

    print(f"X shape: {X.shape}")
    print(f"y_data shape: {y_data.shape}")

    X_train, X_val, y_train, y_val = train_test_split(X, y_data, test_size=split)#, random_state=235)

    train_dataset = RegressionDataset(torch.from_numpy(X_train).float(),
                                      torch.from_numpy(y_train).float() / ynormfac)

    val_dataset = RegressionDataset(torch.from_numpy(X_val).float(), torch.from_numpy(y_val).float() / ynormfac)

    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size_, shuffle=True)
    val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size_)

    return train_loader, val_loader

# Model Base Class
class Model(nn.Module):
    def __init__(self, filepath=None):
        super(Model, self).__init__()
        self.filepath = filepath or 'default_model.pt'
        self.trainer_config = ''

    def forward(self, x):
        raise NotImplementedError

    def __repr__(self):
        raise NotImplementedError

    def update_filepath(self):
        if not self.filepath:
            raise ValueError("Filepath not initialized")
        cur_dir = os.getcwd()
        self.filepath = os.path.join(cur_dir, 'models', self.__repr__(), self.__repr__() + '.pt')

    def update_trainer_config(self, config):
        self.trainer_config = config
        self.update_filepath()

    def save(self, hidden_size, emb_dim, dropout):
        save_dir = os.path.dirname(self.filepath)
        ensure_directory_exists(save_dir)
        torch.save(self.state_dict(), self.filepath)
        torch.save({
            'hidden_size': hidden_size,
            'emb_dim': emb_dim,
            'dropout': dropout,
            'model_state_dict': self.state_dict()
            }, self.filepath)
        print(f'Model {self.__repr__()} saved')

    def save_checkpoint(self, epoch_num):
        filename = os.path.join(os.path.dirname(self.filepath), self.__repr__() + '_' + str(epoch_num) + '.pt')
        ensure_directory_exists(os.path.dirname(filename))
        torch.save(self.state_dict(), filename)

    def load(self, state_dict=None, cpu=False):
        if state_dict:
            self.load_state_dict(state_dict)
        else:
            if cpu:
                self.load_state_dict(torch.load(self.filepath, map_location=lambda storage, loc: storage))
            else:
                # self.load_state_dict(torch.load(self.filepath))
                self.load_state_dict(torch.load(self.filepath))

    def xavier_initialization(self):
        for name, param in self.named_parameters():
            if 'weight' in name:
                nn.init.xavier_normal_(param)

# Conditional VAE Model
class ConditionalSequenceModel(Model):
    ALPHABET = ['A', 'C', 'G', 'T']

    def __init__(self, n_chars=4, seq_len=10, cond_size=64, bidirectional=True, batch_size=32, hidden_layers=1, hidden_size=32, lin_dim=16, emb_dim=10, dropout=0.1):
        super(ConditionalSequenceModel, self).__init__(output_model_path)
        self.n_chars = n_chars
        self.seq_len = seq_len
        self.hidden_size = hidden_size
        self.emb_dim = emb_dim
        self.dropout = dropout
        self.lin_dim = lin_dim
        self.batch_size = batch_size
        self.cond_size = cond_size
        self.beta = 0.002
        self.lmbd = 0.0002
        self.capacity = 0.0

        self.cprime_size = 20

        self.loss_hist = []

        # self.emb_lstm = nn.LSTM(input_size=n_chars + cond_size, hidden_size=hidden_size, num_layers=hidden_layers, batch_first=True, dropout=dropout if hidden_layers > 1 else 0, bidirectional=bidirectional)
        self.emb_lstm = nn.LSTM(input_size=n_chars, hidden_size=hidden_size, num_layers=hidden_layers, batch_first=True, dropout=dropout if hidden_layers > 1 else 0, bidirectional=bidirectional)
        # self.emb_lstm = nn.LSTM(input_size=n_chars, hidden_size=hidden_size, num_layers=hidden_layers, batch_first=True, dropout=0, bidirectional=bidirectional)
        self.latent_linear = nn.Sequential(
            nn.Linear(hidden_size * seq_len * 2 + cond_size, lin_dim),
            nn.ReLU(),
            nn.Dropout(p=dropout)
        )
        self.latent_mean = nn.Linear(lin_dim, emb_dim)
        self.latent_log_std = nn.Linear(lin_dim, emb_dim)
        # self.latent_mean = nn.Sequential(nn.Linear(lin_dim, emb_dim), nn.Tanh())
        # self.latent_log_std = nn.Sequential(nn.Linear(lin_dim, emb_dim), nn.Tanh())
        self.dec_lin = nn.Sequential(
            nn.Linear(emb_dim + 2*self.cprime_size, emb_dim),
            # nn.Linear(emb_dim, emb_dim),
            nn.ReLU(),
            nn.Dropout(p=dropout)
        )
        self.dec_lstm = nn.LSTM(input_size=emb_dim, hidden_size=hidden_size, num_layers=hidden_layers, dropout=dropout if hidden_layers > 1 else 0, batch_first=True, bidirectional=bidirectional)
        # self.dec_lstm = nn.LSTM(input_size=emb_dim, hidden_size=hidden_size, num_layers=hidden_layers, dropout=0, batch_first=True, bidirectional=bidirectional)
        self.dec_final = nn.Linear(hidden_size * seq_len * 2 + cond_size, n_chars * seq_len)
        # self.dec_cprime1 = nn.Linear(n_chars * seq_len, self.cprime_size*2)
        # self.dec_cprime2 = nn.Linear(n_chars * seq_len, self.cprime_size*2)


        self.dec_cprime1 = nn.Linear(n_chars * seq_len, 2) # Auxiliary Network responsible for predicting the latent codes from the generated data.
        self.dec_cprime2 = nn.Linear(n_chars * seq_len, 2)

        self.xavier_initialization()

    def encode(self, x, c):
        # print("encoder c   ", c)
        x_one_hot = x.float().unsqueeze(2)
        x_one_hot = torch.nn.functional.one_hot(x_one_hot.long(), num_classes=self.n_chars).float()
        x_one_hot = x_one_hot.squeeze(2)
        # print("x   ", x_one_hot.shape)
        # print("c 1    ", c.shape)
        # c = c.unsqueeze(1).repeat(1, x.size(1), 1)
        # c = torch.zeros(c.shape).to(device)
        # print("c 2    ", c.shape)
        # xc = torch.cat((x_one_hot, c), dim=-1)
        # print("xc    ", xc.shape)
        # xc = x_one_hot
        hidden, _ = self.emb_lstm(x_one_hot)
        hidden = torch.flatten(hidden, 1)
        # print("hidden    ", hidden.shape)
        # print("c    ", c.shape)
        # print("hidden    ", hidden)
        # print("c    ", c[0,:])
        # print("c    ", c[1,:])
        # print("c    ", c[2,:])
        # c = torch.zeros(c.shape).to(device)
        hidden = torch.cat((hidden, c), dim=-1)
        hidden = self.latent_linear(hidden)
        
        z_mean = self.latent_mean(hidden)
        z_log_std = self.latent_log_std(hidden)
        # print("mean   ", z_mean)
        # print("std    ", z_log_std)
        return torch.distributions.Normal(loc=z_mean, scale=torch.exp(z_log_std)), z_mean, z_log_std

    def decode(self, z, c):
        # c = torch.zeros(c.shape).to(device)
        # print("dedcode   ")
        # print("z   ", z.shape)
        # print("c   ", c.shape)
        # zc = torch.cat((z, c), dim=1)
        # zc = z
        hidden = self.dec_lin(z)
        hidden = hidden.unsqueeze(1).repeat(1, self.seq_len, 1)
        hidden, _ = self.dec_lstm(hidden)
        conc = torch.cat((torch.flatten(hidden, 1), c), dim=1)
        out = self.dec_final(conc)
        out_c1 = self.dec_cprime1(out) #the auxiliary network's prediction of the latent codes
        out_c2 = self.dec_cprime2(out) #predicted latent codes. cprime1, and cprime2 are sampled from a standard normal distribution
        return out.view(-1, self.seq_len, self.n_chars), out_c1, out_c2

    def forward(self, x, c, cprime1, cprime2):
        dist, z_mean, z_log_std = self.encode(x, c)
        # z = dist.rsample()
        z, prior_sample, prior = self.reparametrize(dist)
        ##
        num = x.shape[0]
        z = torch.cat((z, cprime1), dim=-1)
        z = torch.cat((z, cprime2), dim=-1)
        ##
        dec, dec_cprime1, dec_cprime2 = self.decode(z, c)
        return dec, z_mean, z_log_std, cprime1, cprime2, dec_cprime1, dec_cprime2

    def generate(self, c, cprime1, cprime2, nz=50):
        num = c.shape[0]
        z = torch.randn([num, nz]).to(device)
        z = torch.cat((z, cprime1), dim=-1)
        z = torch.cat((z, cprime2), dim=-1)
        rec_x, dec_cprime1, dec_cprime2 = self.decode(z, c=c)
        return rec_x
    
    
    def reparametrize(self, dist):
        sample = dist.rsample()
        prior = torch.distributions.Normal(torch.zeros_like(dist.loc), torch.ones_like(dist.scale))
        prior_sample = prior.sample()
        return sample, prior_sample, prior


    def __repr__(self):
        return "ConditionalSequenceModel"

    @staticmethod
    def mean_crossentropy_loss(weights, targets):
        criteria = nn.CrossEntropyLoss(reduction='mean')
        batch_size, seq_len, num_notes = weights.size()
        assert (batch_size == targets.size(0))
        assert (seq_len == targets.size(1))
        weights = weights.view(-1, num_notes)
        targets = targets.view(-1)
        loss = criteria(weights, targets.long())
        return loss

    @staticmethod
    def mean_accuracy(weights, targets):
        _, max_indices = weights.max(2)
        targets = targets.argmax(dim=2) if targets.dim() > 2 else targets
        correct = max_indices == targets
        # print("weights    ", weights.shape)
        # print("max_indices    ", max_indices.shape)
        # print("targets    ", targets.shape)
        # print("numel    ", targets.numel())
        return torch.sum(correct.float()) / targets.numel()

    @staticmethod
    def reconstruction_loss(x, x_recons):
        return ConditionalSequenceModel.mean_crossentropy_loss(weights=x_recons, targets=x)

    @staticmethod
    def kld_gaussian(mu, log_std):
        return -0.5 * torch.sum(1 + log_std - mu.pow(2) - log_std.exp(), dim=1)

    def total_loss(self, x, c, recons, dist, mu, log_std, random_cp1, random_cp2, outputs_cp1, outputs_cp2):
        recons_loss = self.reconstruction_loss(x, recons)
        kld_loss = torch.mean(self.kld_gaussian(mu, log_std))
        kld_loss = torch.abs(kld_loss - self.capacity)
        mi1 = self.mutual_information_loss(random_cp1, outputs_cp1)
        mi2 = self.mutual_information_loss(random_cp2, outputs_cp2)
        mi = mi1 + mi2
        return recons_loss + self.beta * kld_loss + self.lmbd * mi , recons_loss, kld_loss , mi


    def mutual_information_loss(self, c, c_reconstructed, bins=5):
        '''
        the auxiliary network Q predicts the latent codes c given the generated data x'. By maximizing the likelihood log Q(c|x'),
        we encourage the model to generate data x' that retains information about the latent codes c.
        in implementation, the comparison is between the true latent codes c and the predicted latent codes c' from Q(c|x').
        This comparison is equivalent to maximizing the mutual information I(c,x') because we are maximizing the likelihood that
        Q correctly predicts the true latent codes c from the generated data x'.
        https://github.com/Natsu6767/InfoGAN-PyTorch/blob/master/utils.py
        
        '''

        # # print("c recons    ", c_reconstructed.shape)
        # # print("c    ", c.shape)
        # x_reconstructed_flat = c_reconstructed.view(c_reconstructed.size(0), -1)
        # c_flat = c.view(c.size(0), -1)
        
        # joint_hist = torch.histc(x_reconstructed_flat + c_flat, bins=bins)
        # x_hist = torch.histc(x_reconstructed_flat, bins=bins)
        # c_hist = torch.histc(c_flat, bins=bins)
        
        # p_joint = joint_hist / torch.sum(joint_hist)
        # p_x = x_hist / torch.sum(x_hist)
        # p_c = c_hist / torch.sum(c_hist)
        
        # p_joint = p_joint[p_joint > 0]  # Avoid log(0)
        # p_x = p_x[p_x > 0]
        # p_c = p_c[p_c > 0]

        # # print("1    ", p_joint.shape)
        # # print("2    ", p_x.shape)
        # # print("3    ", p_c.shape)
        
        # mi = torch.sum(p_joint * torch.log(p_joint / (p_x[:, None] * p_c[None, :])))

        # print("c recons    ", c_reconstructed.shape)
        # print("c     ", c.shape)
        mu, var = torch.chunk(c_reconstructed, 2, dim=-1)
        # print("mu    ", mu.shape)
        # print("var    ", var.shape)

        ### for simplicity just commentes the normalization constant term from the full Gaussian log-likelihood formula.
        logmi =  - (c - mu).pow(2).div(var.mul(2.0) + 1e-6) #- 0.5 * (torch.abs(var).mul(2 * np.pi) + 1e-6).log()
        # print("logmi     ", logmi.shape)
        # print("logmi     ", logmi)

        mi = -(logmi.sum(1).mean()) #the negative log-likelihood is used as a loss function
        # print("mii    ", mi)
        
        return mi

# Define the trainer function
def train(model, num_epochs, learning_rate, train_loader, val_loader, output_model_path):
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)  # Added weight decay for L2 regularization
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=50, factor=0.8, verbose=True)
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    best_val_loss = float('inf')  # Initialize best validation loss for early stopping


    # self.loss_hist.append([recons_loss.item(), self.beta * kld_loss.item() , self.lmbd * mi.item()])

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        # running_accuracy = 0.0
        running_accuracy = []
        temp_loss = []
        for X_batch, y_batch in train_loader:
            # print("xbatch   ", X_batch)
            # print("ybatch   ", y_batch)
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            # outputs, _ = model(X_batch, y_batch)
            cprime1 = torch.randn([X_batch.shape[0], model.cprime_size]).to(device)
            cprime2 = torch.randn([X_batch.shape[0], model.cprime_size]).to(device)
            outputs, z_mean, z_log_std, random_cp1, random_cp2, outputs_cp1, outputs_cp2 = model(X_batch, y_batch, cprime1, cprime2)
            # loss = criterion(outputs.view(-1, model.n_chars), X_batch.view(-1).long())
            # loss = model.mean_crossentropy_loss(outputs, X_batch.long())
            loss, rc_loss, kld_loss, mi_loss = model.total_loss(X_batch.long(), y_batch, outputs, None, z_mean, z_log_std, random_cp1, random_cp2, outputs_cp1, outputs_cp2)
            temp_loss.append([rc_loss.item(), model.beta * kld_loss.item() , model.lmbd * mi_loss.item()])
            # temp_loss.append([rc_loss.item(), kld_loss.item() , mi_loss.item()])
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            accuracy = ConditionalSequenceModel.mean_accuracy(outputs, X_batch)
            # running_accuracy += accuracy.item()
            running_accuracy.append(accuracy.item())

        epoch_loss = running_loss / len(train_loader)
        # epoch_accuracy = running_accuracy / len(train_loader)
        epoch_accuracy = np.mean(running_accuracy)
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)
        ##
        temp_loss = np.array(temp_loss).mean(axis=0)
        # print("temp shape    ", temp_loss.shape)
        model.loss_hist.append(temp_loss)

        # print("X batch    ", X_batch)
        # print("train out   ", outputs.argmax(axis=-1))
        # print("train acc    ", accuracy)
        # print("len    ", len(running_accuracy))
        # print("train acc final   ", epoch_accuracy)


        model.eval()
        val_loss = 0.0
        # val_accuracy = 0.0
        val_accuracy = []
        with torch.no_grad():
            for X_val, y_val in val_loader:
                X_val, y_val = X_val.to(device), y_val.to(device)
                cprime1 = torch.randn([X_val.shape[0], model.cprime_size]).to(device)
                cprime2 = torch.randn([X_val.shape[0], model.cprime_size]).to(device)
                outputs, z_mean, z_log_std, random_cp1, random_cp2, outputs_cp1, outputs_cp2 = model(X_val, y_val, cprime1, cprime2)
                # loss = criterion(outputs.view(-1, model.n_chars), X_val.view(-1).long())
                loss, rc_loss, kld_loss, mi_loss = model.total_loss(X_val.long(), y_val, outputs, None, z_mean, z_log_std, random_cp1, random_cp2, outputs_cp1, outputs_cp2)
                val_loss += loss.item()
                accuracy = ConditionalSequenceModel.mean_accuracy(outputs, X_val)
                # val_accuracy += accuracy.item()
                val_accuracy.append(accuracy.item())

        epoch_val_loss = val_loss / len(val_loader)
        # epoch_val_accuracy = val_accuracy / len(val_loader)
        epoch_val_accuracy = np.mean(val_accuracy)
        val_losses.append(epoch_val_loss)
        val_accuracies.append(epoch_val_accuracy)

        # print("X val    ", X_val)
        # print("val out   ", outputs.argmax(axis=-1))
        # print("val acc    ", accuracy)
        # print("len    ", len(val_accuracy))
        # print("val acc final   ", epoch_val_accuracy)

        # Step the scheduler
        scheduler.step(epoch_val_loss)

        # Early stopping check
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            # torch.save(model.state_dict(), output_model_path)
            model.save(model.hidden_size, model.emb_dim, model.dropout)
            print(f"Model saved to {output_model_path} at epoch {epoch+1}")

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Validation Loss: {epoch_val_loss:.4f}, Train Accuracy: {epoch_accuracy:.4f}, Validation Accuracy: {epoch_val_accuracy:.4f}")

    return train_losses, val_losses, train_accuracies, val_accuracies

def load_checkpoint(model_path):
    checkpoint = torch.load(model_path)
    # print(checkpoint)
    hidden_size = checkpoint['hidden_size']
    emb_dim = checkpoint['emb_dim']
    dpout = checkpoint['dropout']
    model = ConditionalSequenceModel(n_chars=input_size, seq_len=seq_len, cond_size=condition_size, hidden_size=hidden_size, emb_dim=emb_dim, dropout=dpout)
    model.load(checkpoint['model_state_dict'])
    model = model.to(device)
    return model

# %%
# Define a grid of hyperparameters
batch_sizes = [32]
latent_sizes = [30]
learning_rates = [0.001]
hidden_sizes = [6]
condition_sizes = [64]
betas = [0.002]
lambdas = [0.002]

epochs = 200
input_size = 4
output_size = 40
split_ratio = 0.2
ynormfac = 1.0
seq_len = 10

best_val_loss = float('inf')
best_hyperparams = None

for batch_size in batch_sizes:
    for latent_size in latent_sizes:
        for learning_rate in learning_rates:
            for hidden_size in hidden_sizes:
                for condition_size in condition_sizes:
                    for beta in betas:
                        for lmbd in lambdas:
                            print(f"Training with batch_size={batch_size}, latent_size={latent_size}, learning_rate={learning_rate}, hidden_size={hidden_size}, condition_size={condition_size}, beta={beta}, lambda={lmbd}")
                            train_loader, val_loader = load_data_set_seq2seq(file_path, batch_size_=batch_size, split=split_ratio, ynormfac=ynormfac)

                            emb_dim = 50
                            dropout = 0.1
                            model = ConditionalSequenceModel(n_chars=input_size, seq_len=seq_len, cond_size=condition_size, hidden_size=hidden_size, emb_dim=emb_dim, dropout=dropout)
                            model.beta = beta
                            model.lmbd = lmbd
                            model.to(device)

                            train_losses, val_losses, train_accuracies, val_accuracies = train(
                                model, num_epochs=epochs, learning_rate=learning_rate,
                                train_loader=train_loader, val_loader=val_loader,
                                output_model_path=output_model_path
                            )
                            hyperparams_str = (
                                f"\n"
                                f"Batch Size: {batch_size}, Latent Size: {latent_size},Learning Rate: {learning_rate}, Hidden Size: {hidden_size},\n"
                            
                            )
                            plt.figure(figsize=(12, 6))
                            plt.subplot(1, 2, 1)
                            plt.plot(train_losses, label='Train Loss')
                            plt.plot(val_losses, label='Validation Loss')
                            plt.xlabel('Epochs')
                            plt.ylabel('Loss')
                            plt.legend()

                            plt.subplot(1, 2, 2)
                            plt.plot(train_accuracies, label='Train Accuracy')
                            plt.plot(val_accuracies, label='Validation Accuracy')
                            plt.xlabel('Epochs')
                            plt.ylabel('Accuracy')
                            plt.suptitle(hyperparams_str, fontsize=10, y=1)
                            plt.legend()
                            plt.savefig(os.path.join(output_images_path, f'accuracies_latent{latent_size}_hidden{hidden_size}_lr{learning_rate}_beta{beta}_lambda{lmbd}.png'))
                            plt.show()
                            if val_losses[-1] < best_val_loss:
                                best_val_loss = val_losses[-1]
                                best_hyperparams = (batch_size, latent_size, learning_rate, hidden_size, condition_size, beta)

                            ## plot losses
                            d_loss = np.array(model.loss_hist)
                            plt.plot(d_loss[:,0], label="reconstruction loss")
                            plt.plot(d_loss[:,1], label="KLD loss")
                            plt.plot(d_loss[:,2], label="Mutual Information loss")
                            plt.legend()
                            plt.show()
# Out:
# Training with batch_size=32, latent_size=30, learning_rate=0.001, hidden_size=6, condition_size=64, beta=0.002, lambda=0.002
#  ********    dddd     1.0
# X shape: (2098, 10)
# y_data shape: (2098, 64)
# c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 1
# Epoch 1/200, Train Loss: 1.4490, Validation Loss: 1.4792, Train Accuracy: 0.2529, Validation Accuracy: 0.2455
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 2
# Epoch 2/200, Train Loss: 1.4868, Validation Loss: 1.4744, Train Accuracy: 0.2451, Validation Accuracy: 0.2473
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 3
# Epoch 3/200, Train Loss: 1.4787, Validation Loss: 1.4659, Train Accuracy: 0.2458, Validation Accuracy: 0.2527
# Epoch 4/200, Train Loss: 1.4765, Validation Loss: 1.4665, Train Accuracy: 0.2430, Validation Accuracy: 0.2408
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 5
# Epoch 5/200, Train Loss: 1.4709, Validation Loss: 1.4658, Train Accuracy: 0.2466, Validation Accuracy: 0.2529
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 6
# Epoch 6/200, Train Loss: 1.4707, Validation Loss: 1.4643, Train Accuracy: 0.2466, Validation Accuracy: 0.2489
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 7
# Epoch 7/200, Train Loss: 1.4665, Validation Loss: 1.4561, Train Accuracy: 0.2492, Validation Accuracy: 0.2560
# Epoch 8/200, Train Loss: 1.4651, Validation Loss: 1.4633, Train Accuracy: 0.2551, Validation Accuracy: 0.2467
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 9
# Epoch 9/200, Train Loss: 1.4614, Validation Loss: 1.4521, Train Accuracy: 0.2488, Validation Accuracy: 0.2629
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 10
# Epoch 10/200, Train Loss: 1.4591, Validation Loss: 1.4471, Train Accuracy: 0.2560, Validation Accuracy: 0.2721
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 11
# Epoch 11/200, Train Loss: 1.4561, Validation Loss: 1.4412, Train Accuracy: 0.2590, Validation Accuracy: 0.2645
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 12
# Epoch 12/200, Train Loss: 1.4584, Validation Loss: 1.4396, Train Accuracy: 0.2602, Validation Accuracy: 0.2717
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 13
# Epoch 13/200, Train Loss: 1.4483, Validation Loss: 1.4375, Train Accuracy: 0.2677, Validation Accuracy: 0.2714
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 14
# Epoch 14/200, Train Loss: 1.4484, Validation Loss: 1.4355, Train Accuracy: 0.2628, Validation Accuracy: 0.2777
# Epoch 15/200, Train Loss: 1.4462, Validation Loss: 1.4374, Train Accuracy: 0.2658, Validation Accuracy: 0.2761
# Epoch 16/200, Train Loss: 1.4419, Validation Loss: 1.4386, Train Accuracy: 0.2672, Validation Accuracy: 0.2797
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 17
# Epoch 17/200, Train Loss: 1.4401, Validation Loss: 1.4313, Train Accuracy: 0.2744, Validation Accuracy: 0.2859
# Epoch 18/200, Train Loss: 1.4389, Validation Loss: 1.4338, Train Accuracy: 0.2686, Validation Accuracy: 0.2690
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 19
# Epoch 19/200, Train Loss: 1.4364, Validation Loss: 1.4290, Train Accuracy: 0.2730, Validation Accuracy: 0.2815
# Epoch 20/200, Train Loss: 1.4359, Validation Loss: 1.4303, Train Accuracy: 0.2728, Validation Accuracy: 0.2757
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 21
# Epoch 21/200, Train Loss: 1.4331, Validation Loss: 1.4280, Train Accuracy: 0.2744, Validation Accuracy: 0.2922
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 22
# Epoch 22/200, Train Loss: 1.4296, Validation Loss: 1.4206, Train Accuracy: 0.2786, Validation Accuracy: 0.2817
# Epoch 23/200, Train Loss: 1.4265, Validation Loss: 1.4281, Train Accuracy: 0.2810, Validation Accuracy: 0.2728
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 24
# Epoch 24/200, Train Loss: 1.4245, Validation Loss: 1.4170, Train Accuracy: 0.2820, Validation Accuracy: 0.2926
# Epoch 25/200, Train Loss: 1.4256, Validation Loss: 1.4180, Train Accuracy: 0.2806, Validation Accuracy: 0.2781
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 26
# Epoch 26/200, Train Loss: 1.4241, Validation Loss: 1.4170, Train Accuracy: 0.2797, Validation Accuracy: 0.2859
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 27
# Epoch 27/200, Train Loss: 1.4197, Validation Loss: 1.4106, Train Accuracy: 0.2856, Validation Accuracy: 0.2815
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 28
# Epoch 28/200, Train Loss: 1.4191, Validation Loss: 1.4085, Train Accuracy: 0.2883, Validation Accuracy: 0.3016
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 29
# Epoch 29/200, Train Loss: 1.4167, Validation Loss: 1.4070, Train Accuracy: 0.2896, Validation Accuracy: 0.2967
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 30
# Epoch 30/200, Train Loss: 1.4156, Validation Loss: 1.4063, Train Accuracy: 0.2893, Validation Accuracy: 0.3011
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 31
# Epoch 31/200, Train Loss: 1.4127, Validation Loss: 1.4035, Train Accuracy: 0.2891, Validation Accuracy: 0.2946
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 32
# Epoch 32/200, Train Loss: 1.4070, Validation Loss: 1.3955, Train Accuracy: 0.2958, Validation Accuracy: 0.3060
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 33
# Epoch 33/200, Train Loss: 1.4041, Validation Loss: 1.3949, Train Accuracy: 0.2938, Validation Accuracy: 0.3007
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 34
# Epoch 34/200, Train Loss: 1.4023, Validation Loss: 1.3937, Train Accuracy: 0.2975, Validation Accuracy: 0.3069
# Epoch 35/200, Train Loss: 1.3987, Validation Loss: 1.3967, Train Accuracy: 0.2984, Validation Accuracy: 0.2991
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 36
# Epoch 36/200, Train Loss: 1.3974, Validation Loss: 1.3862, Train Accuracy: 0.3030, Validation Accuracy: 0.3042
# Epoch 37/200, Train Loss: 1.3961, Validation Loss: 1.3888, Train Accuracy: 0.3026, Validation Accuracy: 0.3056
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 38
# Epoch 38/200, Train Loss: 1.3956, Validation Loss: 1.3819, Train Accuracy: 0.3050, Validation Accuracy: 0.3156
# Epoch 39/200, Train Loss: 1.3915, Validation Loss: 1.3836, Train Accuracy: 0.3023, Validation Accuracy: 0.3143
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 40
# Epoch 40/200, Train Loss: 1.3887, Validation Loss: 1.3808, Train Accuracy: 0.3065, Validation Accuracy: 0.3098
# Epoch 41/200, Train Loss: 1.3876, Validation Loss: 1.3824, Train Accuracy: 0.3094, Validation Accuracy: 0.3114
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 42
# Epoch 42/200, Train Loss: 1.3822, Validation Loss: 1.3742, Train Accuracy: 0.3127, Validation Accuracy: 0.3170
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 43
# Epoch 43/200, Train Loss: 1.3815, Validation Loss: 1.3675, Train Accuracy: 0.3101, Validation Accuracy: 0.3241
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 44
# Epoch 44/200, Train Loss: 1.3811, Validation Loss: 1.3667, Train Accuracy: 0.3065, Validation Accuracy: 0.3232
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 45
# Epoch 45/200, Train Loss: 1.3780, Validation Loss: 1.3635, Train Accuracy: 0.3099, Validation Accuracy: 0.3132
# Epoch 46/200, Train Loss: 1.3758, Validation Loss: 1.3642, Train Accuracy: 0.3114, Validation Accuracy: 0.3214
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 47
# Epoch 47/200, Train Loss: 1.3709, Validation Loss: 1.3630, Train Accuracy: 0.3165, Validation Accuracy: 0.3214
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 48
# Epoch 48/200, Train Loss: 1.3702, Validation Loss: 1.3577, Train Accuracy: 0.3177, Validation Accuracy: 0.3263
# Epoch 49/200, Train Loss: 1.4170, Validation Loss: 1.4204, Train Accuracy: 0.2965, Validation Accuracy: 0.2993
# Epoch 50/200, Train Loss: 1.4178, Validation Loss: 1.3975, Train Accuracy: 0.2975, Validation Accuracy: 0.2984
# Epoch 51/200, Train Loss: 1.3979, Validation Loss: 1.3799, Train Accuracy: 0.3106, Validation Accuracy: 0.3187
# Epoch 52/200, Train Loss: 1.3830, Validation Loss: 1.3743, Train Accuracy: 0.3143, Validation Accuracy: 0.3266
# Epoch 53/200, Train Loss: 1.3773, Validation Loss: 1.3667, Train Accuracy: 0.3232, Validation Accuracy: 0.3268
# Epoch 54/200, Train Loss: 1.3711, Validation Loss: 1.3618, Train Accuracy: 0.3228, Validation Accuracy: 0.3283
# Epoch 55/200, Train Loss: 1.3669, Validation Loss: 1.3623, Train Accuracy: 0.3298, Validation Accuracy: 0.3397
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 56
# Epoch 56/200, Train Loss: 1.3643, Validation Loss: 1.3537, Train Accuracy: 0.3256, Validation Accuracy: 0.3286
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 57
# Epoch 57/200, Train Loss: 1.3591, Validation Loss: 1.3493, Train Accuracy: 0.3316, Validation Accuracy: 0.3344
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 58
# Epoch 58/200, Train Loss: 1.3553, Validation Loss: 1.3440, Train Accuracy: 0.3330, Validation Accuracy: 0.3397
# Epoch 59/200, Train Loss: 1.3535, Validation Loss: 1.3466, Train Accuracy: 0.3358, Validation Accuracy: 0.3348
# Epoch 60/200, Train Loss: 1.3549, Validation Loss: 1.3456, Train Accuracy: 0.3304, Validation Accuracy: 0.3304
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 61
# Epoch 61/200, Train Loss: 1.3528, Validation Loss: 1.3398, Train Accuracy: 0.3308, Validation Accuracy: 0.3353
# Epoch 62/200, Train Loss: 1.3492, Validation Loss: 1.3400, Train Accuracy: 0.3396, Validation Accuracy: 0.3491
# Epoch 63/200, Train Loss: 1.3481, Validation Loss: 1.3430, Train Accuracy: 0.3394, Validation Accuracy: 0.3417
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 64
# Epoch 64/200, Train Loss: 1.3470, Validation Loss: 1.3344, Train Accuracy: 0.3390, Validation Accuracy: 0.3312
# Epoch 65/200, Train Loss: 1.3804, Validation Loss: 1.4103, Train Accuracy: 0.3418, Validation Accuracy: 0.3500
# Epoch 66/200, Train Loss: 1.4020, Validation Loss: 1.3847, Train Accuracy: 0.3403, Validation Accuracy: 0.3469
# Epoch 67/200, Train Loss: 1.3805, Validation Loss: 1.3658, Train Accuracy: 0.3400, Validation Accuracy: 0.3478
# Epoch 68/200, Train Loss: 1.3683, Validation Loss: 1.3570, Train Accuracy: 0.3478, Validation Accuracy: 0.3587
# Epoch 69/200, Train Loss: 1.3580, Validation Loss: 1.3520, Train Accuracy: 0.3489, Validation Accuracy: 0.3509
# Epoch 70/200, Train Loss: 1.3551, Validation Loss: 1.3482, Train Accuracy: 0.3502, Validation Accuracy: 0.3464
# Epoch 71/200, Train Loss: 1.3518, Validation Loss: 1.3420, Train Accuracy: 0.3455, Validation Accuracy: 0.3487
# Epoch 72/200, Train Loss: 1.3494, Validation Loss: 1.3397, Train Accuracy: 0.3481, Validation Accuracy: 0.3482
# Epoch 73/200, Train Loss: 1.3464, Validation Loss: 1.3351, Train Accuracy: 0.3480, Validation Accuracy: 0.3576
# Epoch 74/200, Train Loss: 1.3442, Validation Loss: 1.3348, Train Accuracy: 0.3523, Validation Accuracy: 0.3460
# Epoch 75/200, Train Loss: 1.3423, Validation Loss: 1.3366, Train Accuracy: 0.3463, Validation Accuracy: 0.3500
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 76
# Epoch 76/200, Train Loss: 1.3401, Validation Loss: 1.3317, Train Accuracy: 0.3496, Validation Accuracy: 0.3531
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 77
# Epoch 77/200, Train Loss: 1.3398, Validation Loss: 1.3314, Train Accuracy: 0.3473, Validation Accuracy: 0.3563
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 78
# Epoch 78/200, Train Loss: 1.3376, Validation Loss: 1.3299, Train Accuracy: 0.3488, Validation Accuracy: 0.3502
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 79
# Epoch 79/200, Train Loss: 1.3363, Validation Loss: 1.3271, Train Accuracy: 0.3517, Validation Accuracy: 0.3594
# Epoch 80/200, Train Loss: 1.3353, Validation Loss: 1.3307, Train Accuracy: 0.3527, Validation Accuracy: 0.3464
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 81
# Epoch 81/200, Train Loss: 1.3357, Validation Loss: 1.3237, Train Accuracy: 0.3492, Validation Accuracy: 0.3594
# Epoch 82/200, Train Loss: 1.3306, Validation Loss: 1.3248, Train Accuracy: 0.3529, Validation Accuracy: 0.3612
# Epoch 83/200, Train Loss: 1.3310, Validation Loss: 1.3246, Train Accuracy: 0.3540, Validation Accuracy: 0.3496
# Epoch 84/200, Train Loss: 1.3301, Validation Loss: 1.3252, Train Accuracy: 0.3518, Validation Accuracy: 0.3529
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 85
# Epoch 85/200, Train Loss: 1.3294, Validation Loss: 1.3223, Train Accuracy: 0.3530, Validation Accuracy: 0.3583
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 86
# Epoch 86/200, Train Loss: 1.3293, Validation Loss: 1.3168, Train Accuracy: 0.3494, Validation Accuracy: 0.3589
# Epoch 87/200, Train Loss: 1.3247, Validation Loss: 1.3213, Train Accuracy: 0.3576, Validation Accuracy: 0.3574
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 88
# Epoch 88/200, Train Loss: 1.3256, Validation Loss: 1.3165, Train Accuracy: 0.3549, Validation Accuracy: 0.3565
# Epoch 89/200, Train Loss: 1.3230, Validation Loss: 1.3188, Train Accuracy: 0.3607, Validation Accuracy: 0.3616
# Epoch 90/200, Train Loss: 1.3251, Validation Loss: 1.3171, Train Accuracy: 0.3574, Validation Accuracy: 0.3621
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 91
# Epoch 91/200, Train Loss: 1.3240, Validation Loss: 1.3146, Train Accuracy: 0.3583, Validation Accuracy: 0.3607
# Epoch 92/200, Train Loss: 1.3226, Validation Loss: 1.3169, Train Accuracy: 0.3635, Validation Accuracy: 0.3574
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 93
# Epoch 93/200, Train Loss: 1.3200, Validation Loss: 1.3139, Train Accuracy: 0.3611, Validation Accuracy: 0.3594
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 94
# Epoch 94/200, Train Loss: 1.3203, Validation Loss: 1.3084, Train Accuracy: 0.3620, Validation Accuracy: 0.3696
# Epoch 95/200, Train Loss: 1.3174, Validation Loss: 1.3088, Train Accuracy: 0.3640, Validation Accuracy: 0.3732
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 96
# Epoch 96/200, Train Loss: 1.3167, Validation Loss: 1.3073, Train Accuracy: 0.3674, Validation Accuracy: 0.3690
# Epoch 97/200, Train Loss: 1.3141, Validation Loss: 1.3080, Train Accuracy: 0.3700, Validation Accuracy: 0.3594
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 98
# Epoch 98/200, Train Loss: 1.3137, Validation Loss: 1.3049, Train Accuracy: 0.3715, Validation Accuracy: 0.3754
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 99
# Epoch 99/200, Train Loss: 1.3133, Validation Loss: 1.3036, Train Accuracy: 0.3667, Validation Accuracy: 0.3752
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 100
# Epoch 100/200, Train Loss: 1.3138, Validation Loss: 1.3014, Train Accuracy: 0.3701, Validation Accuracy: 0.3795
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 101
# Epoch 101/200, Train Loss: 1.3102, Validation Loss: 1.3007, Train Accuracy: 0.3738, Validation Accuracy: 0.3804
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 102
# Epoch 102/200, Train Loss: 1.3085, Validation Loss: 1.2954, Train Accuracy: 0.3767, Validation Accuracy: 0.3857
# Epoch 103/200, Train Loss: 1.3057, Validation Loss: 1.2976, Train Accuracy: 0.3793, Validation Accuracy: 0.3699
# Epoch 104/200, Train Loss: 1.3073, Validation Loss: 1.2980, Train Accuracy: 0.3804, Validation Accuracy: 0.3886
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 105
# Epoch 105/200, Train Loss: 1.3015, Validation Loss: 1.2910, Train Accuracy: 0.3838, Validation Accuracy: 0.3964
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 106
# Epoch 106/200, Train Loss: 1.3008, Validation Loss: 1.2895, Train Accuracy: 0.3845, Validation Accuracy: 0.3900
# Epoch 107/200, Train Loss: 1.2977, Validation Loss: 1.2941, Train Accuracy: 0.3901, Validation Accuracy: 0.3902
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 108
# Epoch 108/200, Train Loss: 1.2964, Validation Loss: 1.2840, Train Accuracy: 0.3921, Validation Accuracy: 0.3958
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 109
# Epoch 109/200, Train Loss: 1.2938, Validation Loss: 1.2824, Train Accuracy: 0.3937, Validation Accuracy: 0.4004
# Epoch 110/200, Train Loss: 1.2926, Validation Loss: 1.2843, Train Accuracy: 0.3941, Validation Accuracy: 0.4000
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 111
# Epoch 111/200, Train Loss: 1.2913, Validation Loss: 1.2780, Train Accuracy: 0.3938, Validation Accuracy: 0.4098
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 112
# Epoch 112/200, Train Loss: 1.2891, Validation Loss: 1.2761, Train Accuracy: 0.3972, Validation Accuracy: 0.4116
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 113
# Epoch 113/200, Train Loss: 1.2851, Validation Loss: 1.2738, Train Accuracy: 0.4057, Validation Accuracy: 0.4167
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 114
# Epoch 114/200, Train Loss: 1.2821, Validation Loss: 1.2697, Train Accuracy: 0.4101, Validation Accuracy: 0.4165
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 115
# Epoch 115/200, Train Loss: 1.2790, Validation Loss: 1.2654, Train Accuracy: 0.4107, Validation Accuracy: 0.4136
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 116
# Epoch 116/200, Train Loss: 1.2774, Validation Loss: 1.2628, Train Accuracy: 0.4147, Validation Accuracy: 0.4192
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 117
# Epoch 117/200, Train Loss: 1.2765, Validation Loss: 1.2612, Train Accuracy: 0.4141, Validation Accuracy: 0.4185
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 118
# Epoch 118/200, Train Loss: 1.2750, Validation Loss: 1.2575, Train Accuracy: 0.4130, Validation Accuracy: 0.4219
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 119
# Epoch 119/200, Train Loss: 1.2719, Validation Loss: 1.2543, Train Accuracy: 0.4171, Validation Accuracy: 0.4437
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 120
# Epoch 120/200, Train Loss: 1.2659, Validation Loss: 1.2503, Train Accuracy: 0.4262, Validation Accuracy: 0.4308
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 121
# Epoch 121/200, Train Loss: 1.2673, Validation Loss: 1.2491, Train Accuracy: 0.4210, Validation Accuracy: 0.4371
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 122
# Epoch 122/200, Train Loss: 1.2594, Validation Loss: 1.2407, Train Accuracy: 0.4289, Validation Accuracy: 0.4375
# Epoch 123/200, Train Loss: 1.2626, Validation Loss: 1.2420, Train Accuracy: 0.4302, Validation Accuracy: 0.4424
# Epoch 124/200, Train Loss: 1.2631, Validation Loss: 1.2420, Train Accuracy: 0.4288, Validation Accuracy: 0.4471
# Epoch 125/200, Train Loss: 1.2543, Validation Loss: 1.2430, Train Accuracy: 0.4325, Validation Accuracy: 0.4339
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 126
# Epoch 126/200, Train Loss: 1.2561, Validation Loss: 1.2363, Train Accuracy: 0.4312, Validation Accuracy: 0.4511
# Epoch 127/200, Train Loss: 1.2552, Validation Loss: 1.2389, Train Accuracy: 0.4341, Validation Accuracy: 0.4453
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 128
# Epoch 128/200, Train Loss: 1.2527, Validation Loss: 1.2345, Train Accuracy: 0.4332, Validation Accuracy: 0.4511
# Epoch 129/200, Train Loss: 1.2529, Validation Loss: 1.2356, Train Accuracy: 0.4321, Validation Accuracy: 0.4438
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 130
# Epoch 130/200, Train Loss: 1.2495, Validation Loss: 1.2276, Train Accuracy: 0.4330, Validation Accuracy: 0.4509
# Epoch 131/200, Train Loss: 1.2475, Validation Loss: 1.2326, Train Accuracy: 0.4415, Validation Accuracy: 0.4484
# Epoch 132/200, Train Loss: 1.2488, Validation Loss: 1.2331, Train Accuracy: 0.4387, Validation Accuracy: 0.4522
# Epoch 133/200, Train Loss: 1.2441, Validation Loss: 1.2288, Train Accuracy: 0.4368, Validation Accuracy: 0.4498
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 134
# Epoch 134/200, Train Loss: 1.2419, Validation Loss: 1.2263, Train Accuracy: 0.4434, Validation Accuracy: 0.4469
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 135
# Epoch 135/200, Train Loss: 1.2440, Validation Loss: 1.2258, Train Accuracy: 0.4398, Validation Accuracy: 0.4531
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 136
# Epoch 136/200, Train Loss: 1.2429, Validation Loss: 1.2233, Train Accuracy: 0.4449, Validation Accuracy: 0.4507
# Epoch 137/200, Train Loss: 1.2377, Validation Loss: 1.2249, Train Accuracy: 0.4457, Validation Accuracy: 0.4569
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 138
# Epoch 138/200, Train Loss: 1.2392, Validation Loss: 1.2183, Train Accuracy: 0.4451, Validation Accuracy: 0.4400
# Epoch 139/200, Train Loss: 1.2374, Validation Loss: 1.2207, Train Accuracy: 0.4403, Validation Accuracy: 0.4478
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 140
# Epoch 140/200, Train Loss: 1.2354, Validation Loss: 1.2168, Train Accuracy: 0.4484, Validation Accuracy: 0.4529
# Epoch 141/200, Train Loss: 1.2358, Validation Loss: 1.2175, Train Accuracy: 0.4426, Validation Accuracy: 0.4556
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 142
# Epoch 142/200, Train Loss: 1.2310, Validation Loss: 1.2167, Train Accuracy: 0.4469, Validation Accuracy: 0.4536
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 143
# Epoch 143/200, Train Loss: 1.2323, Validation Loss: 1.2162, Train Accuracy: 0.4514, Validation Accuracy: 0.4580
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 144
# Epoch 144/200, Train Loss: 1.2296, Validation Loss: 1.2143, Train Accuracy: 0.4494, Validation Accuracy: 0.4491
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 145
# Epoch 145/200, Train Loss: 1.2251, Validation Loss: 1.2110, Train Accuracy: 0.4580, Validation Accuracy: 0.4625
# Epoch 146/200, Train Loss: 1.2266, Validation Loss: 1.2130, Train Accuracy: 0.4531, Validation Accuracy: 0.4576
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 147
# Epoch 147/200, Train Loss: 1.2236, Validation Loss: 1.2063, Train Accuracy: 0.4561, Validation Accuracy: 0.4645
# Epoch 148/200, Train Loss: 1.2219, Validation Loss: 1.2098, Train Accuracy: 0.4509, Validation Accuracy: 0.4598
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 149
# Epoch 149/200, Train Loss: 1.2226, Validation Loss: 1.2023, Train Accuracy: 0.4561, Validation Accuracy: 0.4690
# Epoch 150/200, Train Loss: 1.2211, Validation Loss: 1.2048, Train Accuracy: 0.4542, Validation Accuracy: 0.4696
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 151
# Epoch 151/200, Train Loss: 1.2116, Validation Loss: 1.2011, Train Accuracy: 0.4634, Validation Accuracy: 0.4714
# Epoch 152/200, Train Loss: 1.2138, Validation Loss: 1.2016, Train Accuracy: 0.4565, Validation Accuracy: 0.4670
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 153
# Epoch 153/200, Train Loss: 1.2091, Validation Loss: 1.2001, Train Accuracy: 0.4648, Validation Accuracy: 0.4663
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 154
# Epoch 154/200, Train Loss: 1.2110, Validation Loss: 1.1954, Train Accuracy: 0.4592, Validation Accuracy: 0.4679
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 155
# Epoch 155/200, Train Loss: 1.2049, Validation Loss: 1.1888, Train Accuracy: 0.4638, Validation Accuracy: 0.4721
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 156
# Epoch 156/200, Train Loss: 1.2049, Validation Loss: 1.1887, Train Accuracy: 0.4666, Validation Accuracy: 0.4752
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 157
# Epoch 157/200, Train Loss: 1.2023, Validation Loss: 1.1867, Train Accuracy: 0.4665, Validation Accuracy: 0.4801
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 158
# Epoch 158/200, Train Loss: 1.1997, Validation Loss: 1.1821, Train Accuracy: 0.4759, Validation Accuracy: 0.4730
# Epoch 159/200, Train Loss: 1.1971, Validation Loss: 1.1839, Train Accuracy: 0.4700, Validation Accuracy: 0.4795
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 160
# Epoch 160/200, Train Loss: 1.1966, Validation Loss: 1.1774, Train Accuracy: 0.4701, Validation Accuracy: 0.4862
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 161
# Epoch 161/200, Train Loss: 1.1959, Validation Loss: 1.1764, Train Accuracy: 0.4761, Validation Accuracy: 0.4842
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 162
# Epoch 162/200, Train Loss: 1.1923, Validation Loss: 1.1728, Train Accuracy: 0.4766, Validation Accuracy: 0.4886
# Epoch 163/200, Train Loss: 1.1885, Validation Loss: 1.1735, Train Accuracy: 0.4833, Validation Accuracy: 0.4926
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 164
# Epoch 164/200, Train Loss: 1.1848, Validation Loss: 1.1683, Train Accuracy: 0.4832, Validation Accuracy: 0.4830
# Epoch 165/200, Train Loss: 1.1847, Validation Loss: 1.1713, Train Accuracy: 0.4784, Validation Accuracy: 0.4792
# Epoch 166/200, Train Loss: 1.1819, Validation Loss: 1.1688, Train Accuracy: 0.4848, Validation Accuracy: 0.4835
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 167
# Epoch 167/200, Train Loss: 1.1825, Validation Loss: 1.1664, Train Accuracy: 0.4812, Validation Accuracy: 0.4864
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 168
# Epoch 168/200, Train Loss: 1.1807, Validation Loss: 1.1621, Train Accuracy: 0.4844, Validation Accuracy: 0.4917
# Epoch 169/200, Train Loss: 1.1724, Validation Loss: 1.1644, Train Accuracy: 0.4921, Validation Accuracy: 0.4871
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 170
# Epoch 170/200, Train Loss: 1.1711, Validation Loss: 1.1598, Train Accuracy: 0.4904, Validation Accuracy: 0.4875
# Epoch 171/200, Train Loss: 1.1729, Validation Loss: 1.1606, Train Accuracy: 0.4896, Validation Accuracy: 0.4946
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 172
# Epoch 172/200, Train Loss: 1.1673, Validation Loss: 1.1573, Train Accuracy: 0.4922, Validation Accuracy: 0.4946
# Epoch 173/200, Train Loss: 1.1675, Validation Loss: 1.1576, Train Accuracy: 0.4963, Validation Accuracy: 0.4895
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 174
# Epoch 174/200, Train Loss: 1.1629, Validation Loss: 1.1525, Train Accuracy: 0.4969, Validation Accuracy: 0.4960
# Epoch 175/200, Train Loss: 1.1609, Validation Loss: 1.1569, Train Accuracy: 0.4994, Validation Accuracy: 0.5033
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 176
# Epoch 176/200, Train Loss: 1.1600, Validation Loss: 1.1513, Train Accuracy: 0.5002, Validation Accuracy: 0.5100
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 177
# Epoch 177/200, Train Loss: 1.1547, Validation Loss: 1.1510, Train Accuracy: 0.5011, Validation Accuracy: 0.5089
# Epoch 178/200, Train Loss: 1.1549, Validation Loss: 1.1519, Train Accuracy: 0.4964, Validation Accuracy: 0.5040
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 179
# Epoch 179/200, Train Loss: 1.1553, Validation Loss: 1.1478, Train Accuracy: 0.5006, Validation Accuracy: 0.5060
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 180
# Epoch 180/200, Train Loss: 1.1515, Validation Loss: 1.1477, Train Accuracy: 0.5047, Validation Accuracy: 0.5051
# Epoch 181/200, Train Loss: 1.1511, Validation Loss: 1.1478, Train Accuracy: 0.5049, Validation Accuracy: 0.5049
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 182
# Epoch 182/200, Train Loss: 1.1494, Validation Loss: 1.1468, Train Accuracy: 0.5068, Validation Accuracy: 0.5080
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 183
# Epoch 183/200, Train Loss: 1.1483, Validation Loss: 1.1462, Train Accuracy: 0.5058, Validation Accuracy: 0.5056
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 184
# Epoch 184/200, Train Loss: 1.1451, Validation Loss: 1.1432, Train Accuracy: 0.5079, Validation Accuracy: 0.5042
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 185
# Epoch 185/200, Train Loss: 1.1452, Validation Loss: 1.1402, Train Accuracy: 0.5086, Validation Accuracy: 0.5116
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 186
# Epoch 186/200, Train Loss: 1.1393, Validation Loss: 1.1378, Train Accuracy: 0.5088, Validation Accuracy: 0.5076
# Epoch 187/200, Train Loss: 1.1412, Validation Loss: 1.1388, Train Accuracy: 0.5095, Validation Accuracy: 0.5132
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 188
# Epoch 188/200, Train Loss: 1.1387, Validation Loss: 1.1372, Train Accuracy: 0.5143, Validation Accuracy: 0.5145
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 189
# Epoch 189/200, Train Loss: 1.1385, Validation Loss: 1.1345, Train Accuracy: 0.5113, Validation Accuracy: 0.5143
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 190
# Epoch 190/200, Train Loss: 1.1331, Validation Loss: 1.1321, Train Accuracy: 0.5137, Validation Accuracy: 0.5098
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 191
# Epoch 191/200, Train Loss: 1.1318, Validation Loss: 1.1313, Train Accuracy: 0.5127, Validation Accuracy: 0.5156
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 192
# Epoch 192/200, Train Loss: 1.1311, Validation Loss: 1.1274, Train Accuracy: 0.5159, Validation Accuracy: 0.5083
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 193
# Epoch 193/200, Train Loss: 1.1262, Validation Loss: 1.1247, Train Accuracy: 0.5186, Validation Accuracy: 0.5129
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 194
# Epoch 194/200, Train Loss: 1.1266, Validation Loss: 1.1210, Train Accuracy: 0.5167, Validation Accuracy: 0.5192
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 195
# Epoch 195/200, Train Loss: 1.1219, Validation Loss: 1.1169, Train Accuracy: 0.5185, Validation Accuracy: 0.5286
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 196
# Epoch 196/200, Train Loss: 1.1190, Validation Loss: 1.1121, Train Accuracy: 0.5257, Validation Accuracy: 0.5310
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 197
# Epoch 197/200, Train Loss: 1.1145, Validation Loss: 1.1064, Train Accuracy: 0.5230, Validation Accuracy: 0.5312
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 198
# Epoch 198/200, Train Loss: 1.1087, Validation Loss: 1.1058, Train Accuracy: 0.5289, Validation Accuracy: 0.5259
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 199
# Epoch 199/200, Train Loss: 1.1059, Validation Loss: 1.0997, Train Accuracy: 0.5310, Validation Accuracy: 0.5266
# Model ConditionalSequenceModel saved
# Model saved to model/cvae_model_vmim_2.pt at epoch 200
# Epoch 200/200, Train Loss: 1.1022, Validation Loss: 1.0931, Train Accuracy: 0.5344, Validation Accuracy: 0.5424
